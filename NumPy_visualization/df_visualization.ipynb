# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
ts = pd.Series(np.random.randint(0,100,1000),
                index=pd.date_range("1/1/2020",periods=1000))
ts
# Out:
# 2020-01-01    60
# 2020-01-02     4
# 2020-01-03    73
# 2020-01-04    65
# 2020-01-05    57
#               ..
# 2022-09-22    57
# 2022-09-23    79
# 2022-09-24    40
# 2022-09-25    11
# 2022-09-26    23
# Freq: D, Length: 1000, dtype: int32

# %%
#cumulative sum
ts.cumsum()
# Out:
# 2020-01-01       60
# 2020-01-02       64
# 2020-01-03      137
# 2020-01-04      202
# 2020-01-05      259
#               ...
# 2022-09-22    48759
# 2022-09-23    48838
# 2022-09-24    48878
# 2022-09-25    48889
# 2022-09-26    48912
# Freq: D, Length: 1000, dtype: int32

# %%
ts = ts.cumsum()
ts.plot();
